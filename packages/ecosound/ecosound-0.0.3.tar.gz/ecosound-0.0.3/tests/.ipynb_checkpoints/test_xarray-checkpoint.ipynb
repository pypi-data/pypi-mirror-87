# %%
import xarray
import numpy as np
import os
import time
import datetime as dt

# %%
infile=r'C:\Users\xavier.mouy\Documents\PhD\Projects\Dectector\DFO_RCA_run\RCA_In_Oct17_Dec3_2018_67674121\67674121.181016103806.wav.nc'

# %%
def xr_sort(ds):
    #return ds.sortby(ds.time_min_date,ascending=True)
    return ds.sortby(ds.date,ascending=True)

def to_drop_vars(ds):
    return [x for x in list(ds.variables) if x not in ['date','time_min_date','label_class','label_subclass','confidence']] 

def fix_duplicates(ds):
    index=range(0,len(ds['date']))
    _, unique_index = np.unique(ds['date'], return_index=True)
    index = np.delete(index,unique_index)
    if len(index)>0:
        rnd = np.round(np.random.rand(len(index))*100)-50
        rnd[rnd==0]=1
        rnd_offset =[np.timedelta64(int(x),'ns') for x in rnd]
        time_ax = ds['date'].data
        time_ax[index] = time_ax[index] + rnd_offset
        ds['date'] = time_ax
    #ds.time_min_date = time_ax
    return ds

def preprocess_func(ds):
    return xr_sort(fix_duplicates(ds.drop(to_drop_vars(ds))))

# %%
ds=xarray.open_dataset(infile)
ds
# Out:
# <xarray.Dataset>
# Dimensions:                   (date: 4374)
# Coordinates:
#   * date                      (date) datetime64[ns] 2018-10-16T11:07:05.54000...
# Data variables:
#     uuid                      (date) object ...
#     from_detector             (date) bool ...
#     software_name             (date) object ...
#     software_version          (date) object ...
#     operator_name             (date) object ...
#     UTC_offset                (date) float64 ...
#     entry_date                (date) datetime64[ns] ...
#     audio_channel             (date) int64 ...
#     audio_file_name           (date) object ...
#     audio_file_dir            (date) object ...
#     audio_file_extension      (date) object ...
#     audio_file_start_date     (date) datetime64[ns] ...
#     audio_sampling_frequency  (date) int64 ...
#     audio_bit_depth           (date) int64 ...
#     mooring_platform_name     (date) object ...
#     recorder_type             (date) object ...
#     recorder_SN               (date) object ...
#     hydrophone_model          (date) object ...
#     hydrophone_SN             (date) object ...
#     hydrophone_depth          (date) float64 ...
#     location_name             (date) object ...
#     location_lat              (date) float64 ...
#     location_lon              (date) float64 ...
#     location_water_depth      (date) float64 ...
#     deployment_ID             (date) object ...
#     frequency_min             (date) float64 ...
#     frequency_max             (date) float64 ...
#     time_min_offset           (date) float64 ...
#     time_max_offset           (date) float64 ...
#     time_min_date             (date) datetime64[ns] ...
#     time_max_date             (date) datetime64[ns] ...
#     duration                  (date) float64 ...
#     label_class               (date) object ...
#     label_subclass            (date) object ...
#     confidence                (date) float64 ...
#     freq_peak                 (date) float64 ...
#     freq_bandwidth            (date) float64 ...
#     freq_bandwidth90          (date) float64 ...
#     freq_pct5                 (date) float64 ...
#     freq_pct25                (date) float64 ...
#     freq_pct50                (date) float64 ...
#     freq_pct75                (date) float64 ...
#     freq_pct95                (date) float64 ...
#     freq_iqr                  (date) float64 ...
#     freq_asymmetry            (date) float64 ...
#     freq_concentration        (date) float64 ...
#     freq_std                  (date) float64 ...
#     freq_kurtosis             (date) float64 ...
#     freq_skewness             (date) float64 ...
#     freq_entropy              (date) float64 ...
#     freq_flatness             (date) float64 ...
#     freq_roughness            (date) float64 ...
#     freq_centroid             (date) float64 ...
#     freq_overall_peak         (date) float64 ...
#     freq_median_mean          (date) float64 ...
#     freq_median_std           (date) float64 ...
#     freq_entropy_mean         (date) float64 ...
#     freq_entropy_std          (date) float64 ...
#     freq_upsweep_mean         (date) float64 ...
#     freq_upsweep_fraction     (date) float64 ...
#     snr                       (date) float64 ...
#     time_peak_sec             (date) float64 ...
#     time_peak_perc            (date) float64 ...
#     time_duration             (date) float64 ...
#     time_duration90           (date) float64 ...
#     time_pct5                 (date) float64 ...
#     time_pct25                (date) float64 ...
#     time_pct50                (date) float64 ...
#     time_pct75                (date) float64 ...
#     time_pct95                (date) float64 ...
#     time_iqr                  (date) float64 ...
#     time_asymmetry            (date) float64 ...
#     time_concentration        (date) float64 ...
#     time_std                  (date) float64 ...
#     time_kurtosis             (date) float64 ...
#     time_skewness             (date) float64 ...
#     time_entropy              (date) float64 ...
#     time_flatness             (date) float64 ...
#     time_roughness            (date) float64 ...
#     time_centroid             (date) float64 ...
# Attributes:
#     datatype:           Measurement
#     measurements_name:  ['uuid', 'freq_peak', 'freq_bandwidth', 'freq_bandwid...
#     measurer_name:      SpectrogramFeatures
#     measurer_version:   0.1

# %%
ds2 = fix_duplicates(ds)
ds2
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-7-77c2fd2785e9> in <module>
# ----> 1 ds2 = fix_duplicates(ds)
#       2 ds2
#
# <ipython-input-4-2eac92a6366f> in fix_duplicates(ds)
#      14     rnd_offset =[np.timedelta64(int(x),'ns') for x in rnd]
#      15     time_ax = ds['date'].data
# ---> 16     time_ax[index] = time_ax[index] + rnd_offset
#      17     ds['date'] = time_ax
#      18     #ds.time_min_date = time_ax
#
# UFuncTypeError: ufunc 'add' cannot use operands with types dtype('<M8[ns]') and dtype('float64')

# %%
index=range(0,len(ds['date']))
_, unique_index = np.unique(ds['date'], return_index=True)
index = np.delete(index,unique_index)
rnd = np.round(np.random.rand(len(index))*100)-50
rnd[rnd==0]=1
rnd_offset =[np.timedelta64(int(x),'ns') for x in rnd]
time_ax = ds['date'].data

# %%
time_ax[index]
# Out:
# array([], dtype='datetime64[ns]')

# %%
index
# Out:
# array([], dtype=int32)

# %%
len(index)
# Out:
# 0
