# %%
# MITO CODE START (DO NOT EDIT)
# SAVED-ANALYSIS-STARTUUID-15c89d0f-dddf-4d6f-8329-30c41a80d4ceSAVED-ANALYSIS-END

from mitosheet import *

# Step 1 (rename headers to make them work with Mito)

blocks.rename(columns={"10T Block 'C'": "10T_Block_C_", "10T Block 'D'": "10T_Block_D_", "10T Block 'E'": "10T_Block_E_"}, inplace=True)

targets.rename(columns={"Subject.1": "Subject_1", "GradeChance1.1": "GradeChance1_1", "GradeChance2.1": "GradeChance2_1", "GradeChance3.1": "GradeChance3_1", "GradeChance4.1": "GradeChance4_1", "GradeChance5.1": "GradeChance5_1", "GradeChance6.1": "GradeChance6_1", "GradeChance7.1": "GradeChance7_1", "GradeChance8.1": "GradeChance8_1", "GradeChance9.1": "GradeChance9_1", "BenchmarkGrade.1": "BenchmarkGrade_1", "Subject.2": "Subject_2", "GradeChance1.2": "GradeChance1_2", "GradeChance2.2": "GradeChance2_2", "GradeChance3.2": "GradeChance3_2", "GradeChance4.2": "GradeChance4_2", "GradeChance5.2": "GradeChance5_2", "GradeChance6.2": "GradeChance6_2", "GradeChance7.2": "GradeChance7_2", "GradeChance8.2": "GradeChance8_2", "GradeChance9.2": "GradeChance9_2", "BenchmarkGrade.2": "BenchmarkGrade_2", "Subject.3": "Subject_3", "GradeChance1.3": "GradeChance1_3", "GradeChance2.3": "GradeChance2_3", "GradeChance3.3": "GradeChance3_3", "GradeChance4.3": "GradeChance4_3", "GradeChance5.3": "GradeChance5_3", "GradeChance6.3": "GradeChance6_3", "GradeChance7.3": "GradeChance7_3", "GradeChance8.3": "GradeChance8_3", "GradeChance9.3": "GradeChance9_3", "BenchmarkGrade.3": "BenchmarkGrade_3", "Subject.4": "Subject_4", "GradeChance1.4": "GradeChance1_4", "GradeChance2.4": "GradeChance2_4", "GradeChance3.4": "GradeChance3_4", "GradeChance4.4": "GradeChance4_4", "GradeChance5.4": "GradeChance5_4", "GradeChance6.4": "GradeChance6_4", "GradeChance7.4": "GradeChance7_4", "GradeChance8.4": "GradeChance8_4", "GradeChance9.4": "GradeChance9_4", "BenchmarkGrade.4": "BenchmarkGrade_4", "Subject.5": "Subject_5", "GradeChance1.5": "GradeChance1_5", "GradeChance2.5": "GradeChance2_5", "GradeChance3.5": "GradeChance3_5", "GradeChance4.5": "GradeChance4_5", "GradeChance5.5": "GradeChance5_5", "GradeChance6.5": "GradeChance6_5", "GradeChance7.5": "GradeChance7_5", "GradeChance8.5": "GradeChance8_5", "GradeChance9.5": "GradeChance9_5", "BenchmarkGrade.5": "BenchmarkGrade_5", "Subject.6": "Subject_6", "GradeChance1.6": "GradeChance1_6", "GradeChance2.6": "GradeChance2_6", "GradeChance3.6": "GradeChance3_6", "GradeChance4.6": "GradeChance4_6", "GradeChance5.6": "GradeChance5_6", "GradeChance6.6": "GradeChance6_6", "GradeChance7.6": "Grad
", "BenchmarkGrade.19": "BenchmarkGrade_19", "Subject.20": "Subject_20", "GradeChance1.20": "GradeChance1_20", "GradeChance2.20": "GradeChance2_20", "GradeChance3.20": "GradeChance3_20", "GradeChance4.20": "GradeChance4_20", "GradeChance5.20": "GradeChance5_20", "GradeChance6.20": "GradeChance6_20", "GradeChance7.20": "GradeChance7_20", "GradeChance8.20": "GradeChance8_20", "GradeChance9.20": "GradeChance9_20", "BenchmarkGrade.20": "BenchmarkGrade_20", "Subject.21": "Subject_21", "GradeChance1.21": "GradeChance1_21", "GradeChance2.21": "GradeChance2_21", "GradeChance3.21": "GradeChance3_21", "GradeChance4.21": "GradeChance4_21", "GradeChance5.21": "GradeChance5_21", "GradeChance6.21": "GradeChance6_21", "GradeChance7.21": "GradeChance7_21", "GradeChance8.21": "GradeChance8_21", "GradeChance9.21": "GradeChance9_21", "BenchmarkGrade.21": "BenchmarkGrade_21", "Sport Studies": "Sport_Studies", "Performing Arts": "Performing_Arts", "Health & Social Care": "Health__Social_Care_"}, inplace=True)

# Step 2

blocks['E'] = MID(blocks['10T_Block_C_'], 5, LEN(blocks['10T_Block_C_']))

blocks['F'] = LEFT(blocks['E'],2)

# Step 3

blocks.rename(columns={"F": "course_1"}, inplace=True)

# Step 4

# Make sure the columns are defined in the correct order

blocks['G'] = 0; blocks['H'] = 0

blocks['G'] = MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_']))

blocks['E'] = MID(blocks['10T_Block_C_'], 5, LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['E'],2)

# Step 5

blocks.rename(columns={"H": "course_2"}, inplace=True)

# Step 6

blocks['I'] = MID(blocks['10T_Block_E_'], 5, LEN(blocks['10T_Block_E_']))

blocks['J'] = LEFT(blocks['I'],2)

blocks['G'] = MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_']))

blocks['course_2'] = LEFT(blocks['G'],2)

blocks['E'] = MID(blocks['10T_Block_C_'], 5, LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['E'],2)

# Step 7

blocks.rename(columns={"J": "course_3"}, inplace=True)

# Step 8

blocks['I'] = MID(blocks['10T_Block_E_'], 5, LEN(blocks['10T_Block_E_']))

blocks['course_3'] = LEFT(blocks['I'],2)

blocks['G'] = MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_']))

blocks['course_2'] = LEFT(blocks['G'],2)

blocks['E'] = MID(blocks['10T_Block_C_'], 5, LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['E'],2)
  
# MITO CODE END (DO NOT EDIT)

# %%
import pandas as pd
import mitosheet

# %%
blocks = pd.read_csv('./blocks.csv')
targets = pd.read_csv('./targets.csv')
triple = pd.read_csv('./triple.csv')

# %%
# Setting up the blocks data. 

# For each of the three courses in the blocks sheet take the following steps
# 1. Create a new column
# 2. Rename the column 'course_1'
# 3. In the column, use the formula, '=LEFT(MID(10T_Block_C_, 5, LEN(10T_Block_C_)), 2)'

# Repeat the above 3 steps for Block_D and Block_E 

mitosheet.sheet(blocks, targets, triple)
# Out:
# MitoWidget(analysis_name='UUID-0f8debc2-bc5d-4e70-8f55-df094324bf6a', code_json='{"imports": "from mitosheet i…

# %%
# MITO CODE START (DO NOT EDIT)
# SAVED-ANALYSIS-STARTUUID-0f8debc2-bc5d-4e70-8f55-df094324bf6aSAVED-ANALYSIS-END

from mitosheet import *

# Step 1 (rename headers to make them work with Mito)

blocks.rename(columns={"10T Block 'C'": "10T_Block_C_", "10T Block 'D'": "10T_Block_D_", "10T Block 'E'": "10T_Block_E_"}, inplace=True)

targets.rename(columns={"Subject.1": "Subject_1", "GradeChance1.1": "GradeChance1_1", "GradeChance2.1": "GradeChance2_1", "GradeChance3.1": "GradeChance3_1", "GradeChance4.1": "GradeChance4_1", "GradeChance5.1": "GradeChance5_1", "GradeChance6.1": "GradeChance6_1", "GradeChance7.1": "GradeChance7_1", "GradeChance8.1": "GradeChance8_1", "GradeChance9.1": "GradeChance9_1", "BenchmarkGrade.1": "BenchmarkGrade_1", "Subject.2": "Subject_2", "GradeChance1.2": "GradeChance1_2", "GradeChance2.2": "GradeChance2_2", "GradeChance3.2": "GradeChance3_2", "GradeChance4.2": "GradeChance4_2", "GradeChance5.2": "GradeChance5_2", "GradeChance6.2": "GradeChance6_2", "GradeChance7.2": "GradeChance7_2", "GradeChance8.2": "GradeChance8_2", "GradeChance9.2": "GradeChance9_2", "BenchmarkGrade.2": "BenchmarkGrade_2", "Subject.3": "Subject_3", "GradeChance1.3": "GradeChance1_3", "GradeChance2.3": "GradeChance2_3", "GradeChance3.3": "GradeChance3_3", "GradeChance4.3": "GradeChance4_3", "GradeChance5.3": "GradeChance5_3", "GradeChance6.3": "GradeChance6_3", "GradeChance7.3": "GradeChance7_3", "GradeChance8.3": "GradeChance8_3", "GradeChance9.3": "GradeChance9_3", "BenchmarkGrade.3": "BenchmarkGrade_3", "Subject.4": "Subject_4", "GradeChance1.4": "GradeChance1_4", "GradeChance2.4": "GradeChance2_4", "GradeChance3.4": "GradeChance3_4", "GradeChance4.4": "GradeChance4_4", "GradeChance5.4": "GradeChance5_4", "GradeChance6.4": "GradeChance6_4", "GradeChance7.4": "GradeChance7_4", "GradeChance8.4": "GradeChance8_4", "GradeChance9.4": "GradeChance9_4", "BenchmarkGrade.4": "BenchmarkGrade_4", "Subject.5": "Subject_5", "GradeChance1.5": "GradeChance1_5", "GradeChance2.5": "GradeChance2_5", "GradeChance3.5": "GradeChance3_5", "GradeChance4.5": "GradeChance4_5", "GradeChance5.5": "GradeChance5_5", "GradeChance6.5": "GradeChance6_5", "GradeChance7.5": "GradeChance7_5", "GradeChance8.5": "GradeChance8_5
", "Subject.19": "Subject_19", "GradeChance1.19": "GradeChance1_19", "GradeChance2.19": "GradeChance2_19", "GradeChance3.19": "GradeChance3_19", "GradeChance4.19": "GradeChance4_19", "GradeChance5.19": "GradeChance5_19", "GradeChance6.19": "GradeChance6_19", "GradeChance7.19": "GradeChance7_19", "GradeChance8.19": "GradeChance8_19", "GradeChance9.19": "GradeChance9_19", "BenchmarkGrade.19": "BenchmarkGrade_19", "Subject.20": "Subject_20", "GradeChance1.20": "GradeChance1_20", "GradeChance2.20": "GradeChance2_20", "GradeChance3.20": "GradeChance3_20", "GradeChance4.20": "GradeChance4_20", "GradeChance5.20": "GradeChance5_20", "GradeChance6.20": "GradeChance6_20", "GradeChance7.20": "GradeChance7_20", "GradeChance8.20": "GradeChance8_20", "GradeChance9.20": "GradeChance9_20", "BenchmarkGrade.20": "BenchmarkGrade_20", "Subject.21": "Subject_21", "GradeChance1.21": "GradeChance1_21", "GradeChance2.21": "GradeChance2_21", "GradeChance3.21": "GradeChance3_21", "GradeChance4.21": "GradeChance4_21", "GradeChance5.21": "GradeChance5_21", "GradeChance6.21": "GradeChance6_21", "GradeChance7.21": "GradeChance7_21", "GradeChance8.21": "GradeChance8_21", "GradeChance9.21": "GradeChance9_21", "BenchmarkGrade.21": "BenchmarkGrade_21", "Sport Studies": "Sport_Studies", "Performing Arts": "Performing_Arts", "Health & Social Care": "Health__Social_Care_"}, inplace=True)

# Step 2

blocks['E'] = 0

# Step 3

blocks.rename(columns={"E": "course_1_code"}, inplace=True)

# Step 4

blocks['course_1_code'] = MID(blocks['10T_Block_C_'],5,LEN(blocks['10T_Block_C_']))

# Step 5

blocks['F'] = 0

# Step 6

blocks.rename(columns={"F": "course_1"}, inplace=True)

# Step 7

blocks['course_1'] = LEFT(blocks['course_1_code'],2)

# Step 8

blocks['G'] = 0

# Step 9

blocks.rename(columns={"G": "course2"}, inplace=True)

# Step 10

blocks['course2'] = LEFT(MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_'])))

blocks['course_1_code'] = MID(blocks['10T_Block_C_'],5,LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['course_1_code'],2)

# Step 11

blocks['course2'] = LEFT(MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_'])), 2)

blocks['course_1_code'] = MID(blocks['10T_Block_C_'],5,LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['course_1_code'],2)

# Step 12

blocks['H'] = 0

# Step 13

blocks.rename(columns={"H": "course3"}, inplace=True)

# Step 14

blocks['course3'] = LEFT(MID(blocks['10T_Block_C_'], 5, LEN(blocks['10T_Block_C_'])), 2)

# Step 15

blocks['course3'] = LEFT(MID(blocks['10T_Block_E_'], 5, LEN(blocks['10T_Block_E_'])), 2)

blocks['course2'] = LEFT(MID(blocks['10T_Block_D_'], 5, LEN(blocks['10T_Block_D_'])), 2)

blocks['course_1_code'] = MID(blocks['10T_Block_C_'],5,LEN(blocks['10T_Block_C_']))

blocks['course_1'] = LEFT(blocks['course_1_code'],2)
  
# MITO CODE END (DO NOT EDIT)

# %%
# We now use a custom built bulk column deletion function to get rid of the 'GradeChance' columns so we can focus on the benchmark grades
targets = targets[targets.columns.drop(list(targets.filter(regex='GradeChance')))]

## We then use a custom built bulk rename function to make the 'BenchmarkGrades' columns identifiable 

# note: 
# 1. we did not find matches for all of the courses in the targets dataset (Food Technology, Art Photography, Engineering, Health and Social Care) 
# 2. we considered 'product design' to be the same as 'design and technology'
# 3. we considered 'Art and Design' to be the same as 'Art'
column_renames = {
'BenchmarkGrade_8': 'Dr',
'Food Technology': 'Tf',
'BenchmarkGrade': 'Ar',
'BenchmarkGrade_3': 'Cp',
'BenchmarkGrade_7': 'Double Award Science', 
'BenchmarkGrade_9': 'English Language', 
'BenchmarkGrade_10': 'English Literature',
'BenchmarkGrade_12': 'Gg',
'Art Photography': 'Ap',
'BenchmarkGrade_13': 'Gm', 
'BenchmarkGrade_14': 'Hi',
'Engineering': 'Ee',
'BenchmarkGrade_11': 'Fr',
'BenchmarkGrade_6': 'Dp',
'Health and Social Care': 'Hc',
'BenchmarkGrade_19': 'Ps', 
'BenchmarkGrade_21': 'So',
'BenchmarkGrade_16': 'Mu',
'BenchmarkGrade_20': 'Rg'
}

targets.rename(columns=column_renames, inplace=True)

# %%
# we then merge the blocks and the targets dataframes together

# In the merge modal:
# 1. set the first sheet to "blocks" and the second sheet to "targets"
# 2. from the blocks sheet, only select the columns, Course_1, Course_2, and Course_3
# 3. from the targets sheet, keep all of the column
# 4. select 'Merge'

# then we merge the triple dataframe in

# In the merge modal:
# 1. set the first sheet to "df4" and the second sheet to "triple"
# 2. from df4, select all of the columns -- double check that they are all selected, the 'select all' button is a bit buggy!
# 3. from triple, select the "Triple" column
# 4. select "Merge"

#Lastly, move the Triple column to the right of "Course_3" column

mitosheet.sheet(blocks, targets, triple)
# Out:
# MitoWidget(analysis_name='UUID-40f3b9e1-6037-4602-b187-61d768c4bab3', code_json='{"imports": "from mitosheet i…

# %%
# MITO CODE START (DO NOT EDIT)
# SAVED-ANALYSIS-STARTUUID-40f3b9e1-6037-4602-b187-61d768c4bab3SAVED-ANALYSIS-END

from mitosheet import *

# Step 1 (rename headers to make them work with Mito)

targets.rename(columns={"Double Award Science": "Double_Award_Science", "English Language": "English_Language", "English Literature": "English_Literature"}, inplace=True)

# Step 2

temp_df = targets.drop_duplicates(subset='UPN')

blocks_tmp = blocks.drop(['10T_Block_D_', '10T_Block_E_', 'course_1_code', '10T_Block_C_'], axis=1)

df4 = blocks_tmp.merge(temp_df, left_on=['UPN'], right_on=['UPN'], how='left', suffixes=['_blocks', '_targets'])
  
# MITO CODE END (DO NOT EDIT)
